# %% [markdown]
# ## CURVAS DE APRENDIZAJE

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Leer el archivo CSV
df = pd.read_csv('rewards_per_episode.csv')

# Graficar
plt.figure(figsize=(10,5))
plt.plot(df['episode'], df['reward_obtained'].rolling(100).mean(), label='Reward por episodio')
plt.xlabel('Episodio')
plt.ylabel('Recompensa acumulada')
plt.title('Curva de aprendizaje Q-learning')
plt.legend()
plt.grid(True)
plt.show()
